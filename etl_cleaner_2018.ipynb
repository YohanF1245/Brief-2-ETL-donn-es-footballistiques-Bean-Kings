# %% [markdown]
# Pré-requis
# Installe la librairie pour gérer les accents si ce n'est pas fait :

# %%
pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /opt/anaconda3/lib/python3.12/site-packages (1.3.8)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Cellule 1 : Imports et Configuration
# On ajoute numpy et unidecode pour le nettoyage.

# %%
import json
import pandas as pd
import numpy as np
import os
from unidecode import unidecode # Pour enlever les accents

# Fonction de nettoyage de texte (Règle 2, 3, 4, 7)
def clean_text(text):
    if pd.isna(text) or text == "":
        return "unknown"
    # Minuscule + Sans accent + Strip
    return unidecode(str(text)).lower().strip()

print("✅ Bibliothèques chargées et fonctions prêtes.")
# Out:
# ✅ Bibliothèques chargées et fonctions prêtes.

# %% [markdown]
# Cellule 3 : Extraction (Extract)
# Ici, on récupère les données brutes. Note importante : Je renomme immédiatement les colonnes pour qu'elles correspondent à tes règles (ex: home_result du JSON devient home_goals).
# code

# %%
# 1. Chargement
with open('data/data_2018.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# 2. Mappings (Lookups)
teams_map = {t['id']: t['name'] for t in data['teams']}
stadiums_map = {s['id']: s['city'] for s in data['stadiums']}

# 3. Extraction
all_matches = []

# Fonction interne pour traiter une liste de matchs
def process_matches(match_list, round_name):
    for m in match_list:
        all_matches.append({
            'date': m['date'],
            'round': round_name,
            'city': stadiums_map.get(m['stadium']),
            'home_team_name': teams_map.get(m['home_team']),
            'away_team_name': teams_map.get(m['away_team']),
            'home_goals': m['home_result'], # Attention : Dans le JSON c'est le score
            'away_goals': m['away_result'], # Attention : Dans le JSON c'est le score
            'edition': 2018
        })

# Boucle Groupes
for k, v in data['groups'].items():
    process_matches(v['matches'], v['name'])

# Boucle Finales
for k, v in data['knockout'].items():
    process_matches(v['matches'], v['name'])

# Création du DataFrame brut
df = pd.DataFrame(all_matches)

print(f"📊 Extraction terminée : {len(df)} matchs récupérés.")
display(df.head(3))
# Out:
# 📊 Extraction terminée : 64 matchs récupérés.
#                         date    round              city home_team_name  \
# 0  2018-06-14T18:00:00+03:00  Group A            Moscow         Russia
# 1  2018-06-15T17:00:00+05:00  Group A     Yekaterinburg          Egypt
# 2  2018-06-19T21:00:00+03:00  Group A  Saint Petersburg         Russia
#
#   away_team_name  home_goals  away_goals  edition
# 0   Saudi Arabia           5           0     2018
# 1        Uruguay           0           1     2018
# 2          Egypt           3           1     2018

# %% [markdown]
# Cellule 4 : Transformation & Nettoyage (Transform)
# C'est ici qu'on applique tes règles ETL_RULES.md et qu'on corrige ton erreur de date.

# %%
print("🧹 Démarrage du nettoyage selon ETL_RULES.md...")

# --- RÈGLE 1 : DATE ---
# Correction de ton erreur : On convertit en datetime, puis on formate en string ISO
# Format demandé : YYYY-MM-DD hh:mm:ss
df['date'] = pd.to_datetime(df['date'], utc=True).dt.strftime('%Y-%m-%d %H:%M:%S')

# --- RÈGLE 3, 4, 7 : TEXTE (Villes, Equipes) ---
# Minuscule, sans accents
text_cols = ['city', 'home_team_name', 'away_team_name']
for col in text_cols:
    df[col] = df[col].apply(clean_text)

# --- RÈGLE 2 : ROUND (Standardisation) ---
df['round'] = df['round'].apply(clean_text)

def standardize_round(val):
    if 'group' in val: return 'group' # Remplace "group a" par "group"
    if 'round of 16' in val: return 'round of 16'
    if 'quarter' in val: return 'quarter-final'
    if 'semi' in val: return 'semi-final'
    if 'third' in val: return 'play-off for third place'
    if 'final' in val: return 'final'
    return val

df['round'] = df['round'].apply(standardize_round)

# --- RÈGLE 5, 6 : GOALS (Entiers) ---
df['home_goals'] = df['home_goals'].fillna(0).astype(int)
df['away_goals'] = df['away_goals'].fillna(0).astype(int)

# --- RÈGLE 8, 9 : CALCUL DU RÉSULTAT (Winner/Loser) ---
# On recrée la colonne home_result et away_result mais avec "winner"/"loser"
conditions = [
    (df['home_goals'] > df['away_goals']),
    (df['home_goals'] < df['away_goals']),
    (df['home_goals'] == df['away_goals'])
]
choices_home = ['winner', 'loser', 'draw']
choices_away = ['loser', 'winner', 'draw']

df['home_result'] = np.select(conditions, choices_home, default='draw')
df['away_result'] = np.select(conditions, choices_away, default='draw')

# Réorganisation des colonnes pour faire propre
cols_order = ['date', 'edition', 'round', 'city', 
              'home_team_name', 'away_team_name', 
              'home_goals', 'away_goals', 
              'home_result', 'away_result']
df = df[cols_order]

print("✨ Nettoyage terminé !")
# Out:
# 🧹 Démarrage du nettoyage selon ETL_RULES.md...
# ✨ Nettoyage terminé !

# %% [markdown]
# Cellule 5 : Affichage Final

# %%
# --- ÉTAPE FINALE : RENOMMAGE ET MISE EN FORME ---

# 1. Dictionnaire de renommage (Ancien nom -> Nouveau nom)
rename_mapping = {
    'date': 'Date',
    'round': 'Stage',
    'city': 'City',
    'home_team_name': 'Home Team Name',
    'away_team_name': 'Away Team Name',
    'home_goals': 'Home Team Goals',
    'away_goals': 'Away Team Goals',
    'home_result': 'Home Result',
    'away_result': 'Away Result'
}

# 2. Application du renommage
df = df.rename(columns=rename_mapping)

# 3. Sélection et Ordre des colonnes (On supprime 'edition' ici en ne le sélectionnant pas)
final_cols = [
    'Date', 
    'Stage', 
    'City', 
    'Home Team Name', 
    'Away Team Name', 
    'Home Team Goals', 
    'Away Team Goals', 
    'Home Result', 
    'Away Result'
]

df = df[final_cols]
print(f"📋 Tableau Final ({len(df)} matchs) :")
print("✨ Tableau finalisé avec les bons noms de colonnes :")
display(df)
# Out:
# 📋 Tableau Final (64 matchs) :
# ✨ Tableau finalisé avec les bons noms de colonnes :
#                    Date                     Stage              City  \
# 0   2018-06-14 15:00:00                     group            moscow
# 1   2018-06-15 12:00:00                     group     yekaterinburg
# 2   2018-06-19 18:00:00                     group  saint petersburg
# 3   2018-06-20 15:00:00                     group     rostov-on-don
# 4   2018-06-25 14:00:00                     group            samara
# 5   2018-06-25 14:00:00                     group         volgograd
# 6   2018-06-15 18:00:00                     group             sochi
# 7   2018-06-15 15:00:00                     group  saint petersburg
# 8   2018-06-20 12:00:00                     group            moscow
# 9   2018-06-20 18:00:00                     group             kazan
# 10  2018-06-25 18:00:00                     group           saransk
# 11  2018-06-25 18:00:00                     group       kaliningrad
# 12  2018-06-16 10:00:00                     group             kazan
# 13  2018-06-16 16:00:00                     group           saransk
# 14  2018-06-21 15:00:00                     group     yekaterinburg
# 15  2018-06-21 12:00:00                     group            samara
# 16  2018-06-26 14:00:00                     group            moscow
# 17  2018-06-26 14:00:00                     group             sochi
# 18  2018-06-16 13:00:00                     group            moscow
# 19  2018-06-16 19:00:00                     group       kaliningrad
# 20  2018-06-21 18:00:00                     group   nizhny novgorod
# 21  2018-06-22 15:00:00                     group         volgograd
# 22  2018-06-26 18:00:00                     group  saint petersburg
# 23  2018-06-26 18:00:00                     group     rostov-on-don
# 24  2018-06-17 18:00:00                     group     rostov-on-don
# 25  2018-06-17 12:00:00                     group            samara
# 26  2018-06-22 12:00:00                     group  saint petersburg
# 27  2018-06-22 18:00:00                     group       kaliningrad
# 28  2018-06-27 18:00:00                     group            moscow
# 29  2018-06-27 18:00:00                     group   nizhny novgorod
# 30  2018-06-17 15:00:00                     group            moscow
# 31  2018-06-18 12:00:00                     group   nizhny novgorod
# 32  2018-06-23 18:00:00                     group             sochi
# 33  2018-06-23 15:00:00                     group     rostov-on-don
# 34  2018-06-27 14:00:00                     group             kazan
# 35  2018-06-27 14:00:00                     group     yekaterinburg
# 36  2018-06-18 15:00:00                     group             sochi
# 37  2018-06-18 18:00:00                     group         volgograd
# 38  2018-06-23 12:00:00                     group            moscow
# 39  2018-06-24 12:00:00                     group   nizhny novgorod
# 40  2018-06-28 18:00:00                     group       kaliningrad
# 41  2018-06-28 18:00:00                     group           saransk
# 42  2018-06-19 15:00:00                     group            moscow
# 43  2018-06-19 12:00:00                     group           saransk
# 44  2018-06-24 18:00:00                     group             kazan
# 45  2018-06-24 15:00:00                     group     yekaterinburg
# 46  2018-06-28 14:00:00                     group         volgograd
# 47  2018-06-28 14:00:00                     group            samara
# 48  2018-06-30 18:00:00               round of 16             sochi
# 49  2018-06-30 14:00:00               round of 16             kazan
# 50  2018-07-01 14:00:00               round of 16            moscow
# 51  2018-07-01 18:00:00               round of 16   nizhny novgorod
# 52  2018-07-02 14:00:00               round of 16            samara
# 53  2018-07-02 18:00:00               round of 16     rostov-on-don
# 54  2018-07-03 14:00:00               round of 16  saint petersburg
# 55  2018-07-03 18:00:00               round of 16            moscow
# 56  2018-07-06 14:00:00             quarter-final   nizhny novgorod
# 57  2018-07-06 18:00:00             quarter-final             kazan
# 58  2018-07-07 18:00:00             quarter-final             sochi
# 59  2018-07-07 14:00:00             quarter-final            samara
# 60  2018-07-10 18:00:00                semi-final  saint petersburg
# 61  2018-07-11 18:00:00                semi-final            moscow
# 62  2018-07-14 14:00:00  play-off for third place  saint petersburg
# 63  2018-07-15 15:00:00                     final            moscow
#
#    Home Team Name Away Team Name  Home Team Goals  Away Team Goals  \
# 0          russia   saudi arabia                5                0
# 1           egypt        uruguay                0                1
# 2          russia          egypt                3                1
# 3         uruguay   saudi arabia                1                0
# 4         uruguay         russia                3                0
# 5    saudi arabia          egypt                2                1
# 6        portugal          spain                3                3
# 7         morocco           iran                0                1
# 8        portugal        morocco                1                0
# 9            iran          spain                0                1
# 10           iran       portugal                1                1
# 11          spain        morocco                2                2
# 12         france      australia                2                1
# 13           peru        denmark                0                1
# 14         france           peru                1                0
# 15        denmark      australia                1                1
# 16        denmark         france                0                0
# 17      australia           peru                0                2
# 18      argentina        iceland                1                1
# 19        croatia        nigeria                2                0
# 20      argentina        croatia                0                3
# 21        nigeria        iceland                2                0
# 22        nigeria      argentina                1                2
# 23        iceland        croatia                1                2
# 24         brazil    switzerland                1                1
# 25     costa rica         serbia                0                1
# 26         brazil     costa rica                2                0
# 27         serbia    switzerland                1                2
# 28         serbia         brazil                0                2
# 29    switzerland     costa rica                2                2
# 30        germany         mexico                0                1
# 31         sweden    south korea                1                0
# 32        germany         sweden                2                1
# 33    south korea         mexico                1                2
# 34    south korea        germany                2                0
# 35         mexico         sweden                0                3
# 36        belgium         panama                3                0
# 37        tunisia        england                1                2
# 38        belgium        tunisia                5                2
# 39        england         panama                6                1
# 40        england        belgium                0                1
# 41         panama        tunisia                1                2
# 42         poland        senegal                1                2
# 43       colombia          japan                1                2
# 44         poland       colombia                0                3
# 45          japan        senegal                2                2
# 46          japan         poland                0                1
# 47        senegal       colombia                0                1
# 48        uruguay       portugal                2                1
# 49         france      argentina                4                3
# 50          spain         russia                1                1
# 51        croatia        denmark                1                1
# 52         brazil         mexico                2                0
# 53        belgium          japan                3                2
# 54         sweden    switzerland                1                0
# 55       colombia        england                1                1
# 56        uruguay         france                0                2
# 57         brazil        belgium                1                2
# 58         russia        croatia                2                2
# 59         sweden        england                0                2
# 60         france        belgium                1                0
# 61        croatia        england                2                1
# 62        belgium        england                2                0
# 63         france        croatia                4                2
#
#    Home Result Away Result
# 0       winner       loser
# 1        loser      winner
# 2       winner       loser
# 3       winner       loser
# 4       winner       loser
# 5       winner       loser
# 6         draw        draw
# 7        loser      winner
# 8       winner       loser
# 9        loser      winner
# 10        draw        draw
# 11        draw        draw
# 12      winner       loser
# 13       loser      winner
# 14      winner       loser
# 15        draw        draw
# 16        draw        draw
# 17       loser      winner
# 18        draw        draw
# 19      winner       loser
# 20       loser      winner
# 21      winner       loser
# 22       loser      winner
# 23       loser      winner
# 24        draw        draw
# 25       loser      winner
# 26      winner       loser
# 27       loser      winner
# 28       loser      winner
# 29        draw        draw
# 30       loser      winner
# 31      winner       loser
# 32      winner       loser
# 33       loser      winner
# 34      winner       loser
# 35       loser      winner
# 36      winner       loser
# 37       loser      winner
# 38      winner       loser
# 39      winner       loser
# 40       loser      winner
# 41       loser      winner
# 42       loser      winner
# 43       loser      winner
# 44       loser      winner
# 45        draw        draw
# 46       loser      winner
# 47       loser      winner
# 48      winner       loser
# 49      winner       loser
# 50        draw        draw
# 51        draw        draw
# 52      winner       loser
# 53      winner       loser
# 54      winner       loser
# 55        draw        draw
# 56       loser      winner
# 57       loser      winner
# 58        draw        draw
# 59       loser      winner
# 60      winner       loser
# 61      winner       loser
# 62      winner       loser
# 63      winner       loser
